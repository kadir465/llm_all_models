# %%
# import library
# örnek metin
# unigram,bigram, trigram
# sonuçları incele

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
documents=[
    "bu çalışma NGRAM çalışmasıdır",
    "bu çalışma TF-IDF çalışmasıdır",
    "bu çalışma llm çalışmasıdır"
]

# %%
vectorizer_unigram=CountVectorizer(ngram_range=(1,1))
X_unigram=vectorizer_unigram.fit_transform(documents)
print(f"unigram feature names: {vectorizer_unigram.get_feature_names_out()}")
# Out:
# unigram feature names: ['bu' 'idf' 'llm' 'ngram' 'tf' 'çalışma' 'çalışmasıdır']

# %%
vectorizer_bigram=CountVectorizer(ngram_range=(2,2))
X_bigram=vectorizer_bigram.fit_transform(documents)
print(f"bigram feature names: {vectorizer_bigram.get_feature_names_out()}")
# Out:
# bigram feature names: ['bu çalışma' 'idf çalışmasıdır' 'llm çalışmasıdır' 'ngram çalışmasıdır'
#  'tf idf' 'çalışma llm' 'çalışma ngram' 'çalışma tf']

# %%
vectorizer_trigram=CountVectorizer(ngram_range=(3,3))
X_trigram=vectorizer_trigram.fit_transform(documents)
print(f"trigram feature names: {vectorizer_trigram.get_feature_names_out()}")
# Out:
# trigram feature names: ['bu çalışma llm' 'bu çalışma ngram' 'bu çalışma tf' 'tf idf çalışmasıdır'
#  'çalışma llm çalışmasıdır' 'çalışma ngram çalışmasıdır' 'çalışma tf idf']
