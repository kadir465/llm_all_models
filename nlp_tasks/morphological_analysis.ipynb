# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
import spacy
nlp=spacy.load("en_core_web_sm")
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.8 MB 1.4 MB/s eta 0:00:09
#      -- ------------------------------------- 0.8/12.8 MB 1.5 MB/s eta 0:00:09
#      --- ------------------------------------ 1.0/12.8 MB 1.1 MB/s eta 0:00:11
#      --- ------------------------------------ 1.0/12.8 MB 1.1 MB/s eta 0:00:11
#      ---- ----------------------------------- 1.6/12.8 MB 1.2 MB/s eta 0:00:10
#      ---- ----------------------------------- 1.6/12.8 MB 1.2 MB/s eta 0:00:10
#      ----- ---------------------------------- 1.8/12.8 MB 1.2 MB/s eta 0:00:10
#      ------- -------------------------------- 2.4/12.8 MB 1.3 MB/s eta 0:00:09
#      -------- ------------------------------- 2.6/12.8 MB 1.3 MB/s eta 0:00:08
# ...

# %%
word="I go to school every day"
doc=nlp(word)
for token in doc:
    print(f"Token: {token.text}, Lemma: {token.lemma_}, POS: {token.pos_}")
# Out:
# Token: I, Lemma: I, POS: PRON
# Token: go, Lemma: go, POS: VERB
# Token: to, Lemma: to, POS: ADP
# Token: school, Lemma: school, POS: NOUN
# Token: every, Lemma: every, POS: DET
# Token: day, Lemma: day, POS: NOUN
